# %% [markdown]
# # Project: Analyzing Macbeth
#
# ## Introduction
# For our first day and first data science project, we're going to do some rudimentry analysis of Shakespeare's classic play: Macbeth! You will get practice working with lists, condtionals and dictionaries, visualizing data, and thinking analytically about data.
#
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section
#
# ## Getting the Data
# Here we start by importing a python package and using it to pull the transcript of Macbeth from the project Gutenberg website. We also preview a few details about what is now stored in the variable macbeth; it's a string with 119,846 characters, the first 500 of which are printed below.

# %%
import requests
macbeth = requests.get('http://www.gutenberg.org/cache/epub/2264/pg2264.txt').text

print(type(macbeth))
print(len(macbeth))
print(macbeth[:500])
# Out:
# <class 'str'>
# 120253
# ﻿
#
# ***The Project Gutenberg's Etext of Shakespeare's First Folio***
# ********************The Tragedie of Macbeth*********************
#
#
#
# *******************************************************************
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#1533) at https://www.gutenberg.org/ebooks/1533
# *********************************

# %% [markdown]
# ## Your Task
#
# Your task is to create a bar graph of the 25 most common words in Shakespeare's Macbeth.
#
#
# A common python programming pattern to counting objects, produce histograms, or update statistics is to make calls to a dictionary as you iterate through a list. For example, given a list of words, you can create a dictionary to store counts and then iterate through the list of words, checking how many times each word has appeared using your dictionary, and updating the dictionary count now that you've seen that word again. The `dictionary.get()` method is very useful in doing this. Read the docstring for the dictionary.get() method and use it along with the pseudocode above to create a bar graph of the 25 most common words from the transcript of Macbeth which has been loaded into a variable 'Macbeth'. Be sure to include a title and appropriate labels for your graph.

# %%
# Your code here

#Clean data
clean_text = macbeth.replace(',', '')
clean_text = clean_text.replace('.', '')
clean_text = clean_text.replace(';', '')
clean_text = clean_text.replace('*', '')
print(clean_text[:500])

# split the text into words:
words_list = clean_text.split()
#print(words_list[:21])

# loop through the words_list to built 
# a dictionary with key is the unique word and the value is the count.
words_dict = {}
for word in words_list:
    key = word.lower()
    if key in words_dict.keys():
        words_dict[key] += 1
    else:
        words_dict[key] = 1
#print (words_dict)

# sort the dictionary by the value to find out the top used ones:
sorted_dict = sorted(words_dict, reverse=True)

s = [(k, d[k]) for k in sorted(d, key=d.get, reverse=True)]
for k, v in s:
    k, v

print(sorted_dict)

# Pseudo-code Outline

# Split the transcript into words
# Create a dictionary
# Iterate through the text of Macbeth
# Update word counts
# Create Bar Graph
# Include descriptive titles and labels
# Out:
# ﻿
#
# The Project Gutenberg's Etext of Shakespeare's First Folio
# The Tragedie of Macbeth
#
#
#
#
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#1533) at https://wwwgutenbergorg/ebooks/1533
#
#
#
#
# This is our 3rd edition of most of these plays  See the index
#
#
# Copyright laws are changing all over the world be sure to check
# the copyri
# ['\ufeff', '~5%', 'zip', 'ysey', 'youths', 'youth', 'yours:', 'yours', 'your@login', 'your', 'young', "youl'd", 'you?', 'you:', 'you)', "you'le", "you'l", 'you!)', 'you', 'yong', 'yoake', 'ynch', 'yew', 'yet?', 'yet', 'yesty', 'yesterdayes', 'yesterday', 'yes', 'yellow', "yell'd", 'yeeld', 'years', "year's", 'year', 'ye', 'yawning', 'y', 'x', 'wrought', 'wrongs', 'wrongly', 'wrong', 'written', 'writes', 'write', 'wretched', 'wrencht', 'wren', 'wrathfull', 'wrath', 'wrapt', 'wrackt', 'wracke', 'wounds', 'wound', "would'st", 'would', 'worthyest', 'worthy', 'worth', 'worst:', 'worst', 'worse', 'worne', 'wormes', 'worme', 'worlds', 'world:', 'world', 'works', 'worke:', 'worke)', 'worke', 'work', 'words:', 'words', 'word:', 'word', 'wooll', 'wooingly', 'wood:', 'wood', 'wonne', 'wonders', 'wonder?', 'wonder', 'women', 'womb', 'womans', 'womanly', 'woman?', 'woman', 'wolfe', 'wofull', 'woe', 'wiues', 'witnest', 'witnesse', 'without', 'within', "wither'd", 'withall:', 'withall', 'with', 'witches', 'witchcraft', 'witch', 'wit', 'wishest', 'wish', 'wisely', 'wisedome', 'wisedom?', 'wise', 'wisdome', "wip'd", 'winters', 'winne', 'winke', 'wing:', 'wing', 'wine', 'windes', 'winde', 'win', 'wilt', 'willing', 'william', 'will)', 'will', 'wilde', 'wil', 'wife?', 'wife:', 'wife', 'wider', 'widdowes', 'wicked', 'why', 'whose', 'whore:', 'whom?', 'whom', 'wholsome', 'whole', "who's", 'who', 'whither', 'white', 'whispers', "whisp'rings", "whin'd", 'whilest', 'whiles', 'while', 'which', 'whetstone', 'whether', 'wherewith', 'whereon', 'wherein', 'wherefore', 'whereby', 'where?', 'where-euer', 'where-about', "where's", 'where', 'whence', 'when?', 'when', 'whay-face?', 'what?', "what's", 'what', 'weyward', 'weyard', 'westerne', 'west', 'were', "wer't", 'went', 'well:', 'well', 'welcome:', 'welcome', 'wel', 'weightie', 'weighes', "weigh'd", 'weepes', 'weepe', 'week', 'weeds:', "wee'le", "wee'ld", "wee'l", 'wee', 'web', 'wearie', 'weares', 'weare', 'wear', 'weapons', 'wealth', 'weale:', 'weale', 'weake:', 'weake', 'we', 'wayward', 'wayting', 'wayle', 'wayes:', 'wayes', 'way?', 'way:', 'way', 'waues', 'water-rugs', 'water', 'watching', 'watchfull', 'watchers:', "watch'd", 'watch', 'wastfull', 'wassell', "wasn't", 'washing', 'wash', "was't", 'was', 'warre', 'warranty', 'warranties', 'warranted', 'warrant', 'warlike', 'warders', 'warder', 'wants', 'wanton', 'want', 'walls', 'walkt', 'walking', 'walke', "walk'd?", "walk'd", 'wakes', 'wake', 'waite', 'wait', 'waile', 'wade', 'vulture', 'vulnerable', 'vtterance', 'vsurpers', 'vsually', 'vsing', 'vse:', 'vse', 'vs?', 'vs:', "vs'd", 'vs', 'vrine', 'vpward', 'vprore', 'vppon', "vpon't", "vpon's", 'vpon', 'vplifted', 'vpbraid', 'vp:', 'vp', 'voyces', 'voyce', "vouch'd", 'voluptuousnesse:', 'volunteers', 'volunteer', 'volume', 'voice', "vnwip'd", 'vnwelcom', 'vnusuall', 'vntye', 'vnto', 'vntitled', 'vntimely', 'vntill', 'vnsure', 'vnspeake', 'vnshrinking', 'vnsex', "vnseam'd", 'vnsanctified', 'vnsafe', 'vnruly:', 'vnruffe', 'vnreall', 'vnprouokes:', "vnprepar'd", 'vnnaturall', 'vnmannerly', "vnmann'd", 'vnmake', 'vnlocke', 'vnlineall', 'vnlesse', 'vnknowne', 'vnkle)', 'vnkle', 'vnkindnesse', 'vniust', 'vniuersall', 'vnity', 'vnguarded', 'vnfortunate', 'vnfold', 'vnfixe', 'vnfelt', 'vndone', 'vndon', "vndivulg'd", 'vnderstood', 'vnderstand', 'vnder-writ', "vnder't", 'vnder', 'vndeeded', 'vndaunted', 'vnbend', 'vnbecomming', 'vnbattered', 'vnattended', 'vnaccompanied', 'vlcerous', 'vizards', 'visitings', 'visited', 'visit', 'vision', 'virus', 'violent', 'villanies', 'villaine?', 'villaine', 'vile', 'viewing', 'viewed', 'view', 'victorie', 'vices', 'vice', 'vessels', 'vessell', 'very', 'vertuous', 'vertues', 'vertue', 'version', 'verity', 'verities', 'venture', 'venom', 'vaulting', 'vault', 'various', 'variety', "vap'rous", 'vantage', "vanquish'd", "vanish'd?", "vanish'd", 'vanish', 'vanilla', 'valued', 'value', 'valours', 'valour', 'valiant', 'v', 'usually', 'using', 'users', 'used', 'use', 'us', 'up', 'unwilling ...

# %% [markdown]
# ## Level Up (Optional)
# This project should take you about an hour and a half to complete. If you're done much more quickly than that and are not behind in the course, feel free to deepen your knowledge by completing any or all of the following tasks until you run out of time:
# * Create a list of top characters by mentions of their names
# * Split the text by which character is talking
# * Create subgraphs of the most common words by character
# * Reduce the string to the text of the play itself. (Remove any initial notes, forward, introduction, appendix, etc.)
# * Come up with some other fun analyses of the text!
#
# ## Summary
# Congratulations! You've got some extra practice combining various data types into useful programming patterns and done an initial analysis of a classic text!
